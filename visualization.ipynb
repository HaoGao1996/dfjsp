# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# play_info = pd.read_csv("play_info.csv")
steps_info = pd.read_csv("steps_info.csv")

# %% [markdown]
# action: 0, tardiness: 2880
# action: 1, tardiness: 2550
# action: 2, tardiness: 3302

# %%
steps_info.columns
# Out:
# Index(['epochs', 'steps', 'epsilon', 'loss', 'reward', 'total_tardiness'], dtype='object')

# %% [markdown]
# action: 0, tardiness: 3252
# action: 1, tardiness: 3248

# %%
steps_info['total_tardiness'].min()
# Out:
# 1729.0

# %%
steps_info[steps_info.index < 2000].plot('steps', 'total_tardiness')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info.plot('steps', 'reward')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info.plot('steps', 'loss')
# Out:
# <AxesSubplot:xlabel='steps'>
