# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# play_info = pd.read_csv("play_info.csv")
steps_info = pd.read_csv("../tmp_result/steps_info.csv")

# %%
steps_info.columns
# Out:
# Index(['epochs', 'steps', 'epsilon', 'loss', 'reward'], dtype='object')

# %%
steps_info['loss'].min()
# Out:
# 4.589017521539064e-07

# %%
steps_info.plot('steps', 'loss')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info.plot('steps', 'reward')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info['reward'].hist()
# Out:
# <AxesSubplot:>
