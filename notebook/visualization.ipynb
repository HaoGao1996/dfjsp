# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# play_info = pd.read_csv("play_info.csv")
steps_info = pd.read_csv("../tmp_result/steps_info.csv")

# %%
steps_info.columns
# Out:
# Index(['epochs', 'steps', 'epsilon', 'loss', 'reward', 'score', 'tardiness'], dtype='object')

# %%
steps_info['loss'].min()
# Out:
# 0.0715704336762428

# %%
steps_info.plot('steps', 'loss')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info['reward'].hist()
# Out:
# <AxesSubplot:>

# %%
steps_info.plot('steps', 'score')
# Out:
# <AxesSubplot:xlabel='steps'>

# %%
steps_info.plot('steps', 'tardiness')
# Out:
# <AxesSubplot:xlabel='steps'>
